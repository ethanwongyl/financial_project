# %%
from dotenv import load_dotenv
import os
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import duckdb
from sqlalchemy import create_engine
import itertools

load_dotenv()
password = os.environ["PG_PASSWORD"]


con = duckdb.connect()
con.execute("INSTALL postgres;")
con.execute("LOAD postgres;")

con.execute(f"""
    ATTACH 'host=localhost dbname=hk_market user=ethanwong password={password}'
    AS pg (TYPE postgres)
""")

plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"],
    "font.size": 10,
    "axes.labelsize": 10,
    "legend.fontsize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
})

# %%
# Single stock, daily data over a date range
df = yf.download("0005.HK", start="2020-01-01", end="2026-08-28")
print(df.head())

# Save to CSV for PostgreSQL
df.to_csv("data/raw/hsbc_0005hk.csv")


#ticker_list = ["0700.HK", "0005.HK", "0388.HK","^HSI"]
#data = yf.download(tickers, start="2020-01-01", end="2025-08-28", group_by="ticker")

#for t in tickers:
#    data[t].to_csv(f"{t.replace(".", "_")}.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker        0005.HK    0005.HK    0005.HK    0005.HK   0005.HK
# Date
# 2020-01-02  43.512096  43.547820  43.297749  43.476370  14629077
# 2020-01-03  43.154854  43.726441  43.047680  43.512096  14419537
# 2020-01-06  42.869045  43.154840  42.726148  42.940493  13809308
# 2020-01-07  42.797611  43.083403  42.726161  43.011956   8818594
# 2020-01-08  42.368916  42.440366  42.047397  42.368916  16826669
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 6
#       2 df = yf.download("0005.HK", start="2020-01-01", end="2026-08-28")
#       3 print(df.head())
#       4
#       5 # Save to CSV for PostgreSQL
# ----> 6 df.to_csv("data/raw/hsbc_0005hk.csv")
#       7
#       8
# ...

# %%
#Get company fundamentals
ticker = yf.Ticker("0388.HK")

print(ticker.info)              # sector, market cap, PE ratio, etc.
print(ticker.financials)        # income statement
print(ticker.balance_sheet)
print(ticker.cashflow)
# Out:
# {'address1': 'Two Exchange Square', 'address2': '8th Floor 8 Connaught Place', 'city': 'Central', 'country': 'Hong Kong', 'phone': '852 2522 1122', 'fax': '852 2295 3106', 'website': 'https://www.hkex.com.hk', 'industry': 'Financial Data & Stock Exchanges', 'industryKey': 'financial-data-stock-exchanges', 'industryDisp': 'Financial Data & Stock Exchanges', 'sector': 'Financial Services', 'sectorKey': 'financial-services', 'sectorDisp': 'Financial Services', 'longBusinessSummary': 'Hong Kong Exchanges and Clearing Limited, together with its subsidiaries, owns and operates stock and futures exchanges, and related clearing houses in Hong Kong, the United Kingdom, and Mainland China. It operates through Cash, Equity and Financial Derivatives, Commodities, and Data and Connectivity segments. The Cash segment covers various equity products traded on the cash market platforms of the Stock Exchange of Hong Kong Limited, as well as through the Shanghai-Hong Kong and the Shenzhen-Hong Kong sto
# ...

# %%
# Querying a CSV
df = duckdb.query("""
    SELECT *
    FROM read_csv_auto("data/raw/hkex_0388hk.csv")
    LIMIT 10
""").to_df()

df
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Querying a CSV
# ----> 2 df = duckdb.query("""
#       3     SELECT *
#       4     FROM read_csv_auto("data/raw/hkex_0388hk.csv")
#       5     LIMIT 10
#
# IOException: IO Error: No files found that match the pattern "data/raw/hkex_0388hk.csv"

# %%
#Load CSV as SQL tables
password = os.environ["PG_PASSWORD"]
engine = create_engine(f"postgresql://ethanwong:{password}@localhost:5432/hk_market")

load_file = ("data/raw/tencent_0700hk.csv","data/raw/hkex_0388hk.csv","data/raw/hsbc_0005hk.csv","data/raw/HSI.csv")
tabl_name = ("tencent_0700","hkex_0388","hsbc_0005","hsi_index")

#Notes: csv files downloaded from yfinance has two unwanted rows (1,2), which are removed when read;
#Renaming "Price" column to "date" to match column;
#Columns are lowercased so that they can be properly found in SQL

for file, tabl in zip(load_file,tabl_name):
    df = pd.read_csv(file, skiprows=[1, 2])
    df = df.rename(columns={"Price":"date"})
    df.columns = df.columns.str.lower()
    for col in df.columns[1:]:
        df[col] = df[col].astype(float)
    df["date"] = pd.to_datetime(df["date"])
    df["volume"] = df["volume"].astype("int64")
    df.to_sql(tabl, engine, if_exists="replace", index=False)

#df = pd.read_csv("data/raw/tencent_0700hk.csv")
#df.to_sql("tencent_prices", engine, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# File ~/envs/py311/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/envs/py311/lib/python3.11/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# DependentObjectsStillExist: cannot drop table hsbc_0005 because other objects depend on it
# DETAIL:  view trial depends on table hsbc_0005
# ...

# %%
###Checking data

tables = ["tencent_0700", "hkex_0388", "hsbc_0005", "hsi_index"]
for t in tables:
    df = pd.read_sql(f"SELECT * FROM {t} LIMIT 5", engine)
    print(f"--- {t} ---")
    print(df.dtypes)
    print(df.head(), "\n")
# Out:
# --- tencent_0700 ---
# date      datetime64[us]
# close            float64
# high             float64
# low              float64
# open             float64
# volume             int64
# dtype: object
#         date       close        high         low        open    volume
# 0 2020-01-02  336.371216  338.482311  330.389698  330.565640  15176989
# 1 2020-01-03  336.898895  343.056324  335.315567  341.297054  16611161
# 2 2020-01-06  331.972961  334.259997  330.213692  334.259997  13150847
# 3 2020-01-07  339.185944  341.121155  334.260018  334.963726  19185574
# 4 2020-01-08  336.019287  339.361885  333.556310  336.371141  16845521
#
# --- hkex_0388 ---
# date      datetime64[us]
# close            float64
# high             float64
# low              float64
# open             float64
# volume             int64
# dtype: object
#         date       close        high         low        open    volume
# 0 2020-01-02  220.141312  222.170259  213.378138  214.223534   7135253
# ...

# %%
con.sql("""SELECT * FROM pg.hsbc_0005 WHERE date = '2026-03-30'""").show()
# Out:
# ┌─────────────────────┬───────────────────┬───────────────────┬────────────────────┬───────────────────┬──────────┐
# │        date         │       close       │       high        │        low         │       open        │  volume  │
# │      timestamp      │      double       │      double       │       double       │      double       │  int64   │
# ├─────────────────────┼───────────────────┼───────────────────┼────────────────────┼───────────────────┼──────────┤
# │ 2026-03-30 00:00:00 │ 122.8377914428711 │ 122.8377914428711 │ 120.55197945662763 │ 121.9433399776688 │ 17920263 │
# └─────────────────────┴───────────────────┴───────────────────┴────────────────────┴───────────────────┴──────────┘

# %%
###Formulate daily return for HSBC
## Daily return = (close/prev_close -1) OR (close - prev_close)/prev_close

con.execute("""
CREATE OR REPLACE VIEW hsbc_return AS
SELECT date, close, LAG(close) OVER (ORDER BY DATE) AS prev_close, (close/prev_close -1) AS daily_return
FROM pg.hsbc_0005
""")

con.sql("SELECT * FROM hsbc_return").show()

#returns_df = con.sql("SELECT * FROM hsbc_return WHERE daily_return IS NOT NULL").df()
#returns_df['daily_return'].describe()
# Out:
# ┌─────────────────────┬────────────────────┬────────────────────┬────────────────────────┐
# │        date         │       close        │     prev_close     │      daily_return      │
# │      timestamp      │       double       │       double       │         double         │
# ├─────────────────────┼────────────────────┼────────────────────┼────────────────────────┤
# │ 2020-01-02 00:00:00 │  43.51210403442383 │               NULL │                   NULL │
# │ 2020-01-03 00:00:00 │  43.15484619140625 │  43.51210403442383 │  -0.008210539364746361 │
# │ 2020-01-06 00:00:00 │  42.86906051635742 │  43.15484619140625 │  -0.006622330984132674 │
# │ 2020-01-07 00:00:00 │    42.797607421875 │  42.86906051635742 │ -0.0016667753765016169 │
# │ 2020-01-08 00:00:00 │  42.36891555786133 │    42.797607421875 │   -0.01001672499557893 │
# │ 2020-01-09 00:00:00 │  42.76187896728516 │  42.36891555786133 │   0.009274804517646507 │
# ...

# %%
### Using sample standard deviation, the s.d. for daily_return of the stock price of HSBC is calculated.
### This query uses a rolling 20-day window to find the s.d., and the annualised s.d. is calculated
### by multiplying sqrt(252), which is the generalised number of trading days in a stock market.

con.execute("""
CREATE OR REPLACE VIEW hsbc_volatility AS
SELECT date, close, daily_return,
        STDDEV_SAMP(daily_return) OVER (ORDER BY date ROWS BETWEEN 19 PRECEDING AND CURRENT ROW) AS volatility_20d,
        volatility_20d * SQRT(252) AS annualised_volatility_20d
        FROM hsbc_return
        WHERE daily_return IS NOT NULL
""")

## Checking data and looking for the most volatile periods in the given period of the stock price

con.sql("""SELECT date, volatility_20d, annualised_volatility_20d FROM hsbc_volatility 
           ORDER BY annualised_volatility_20d DESC
           LIMIT 30
""").show()

## Investigating the most volatile period of this stock price in April 2025, due to the US trade tariff 
## introduced in early April that year. Comparing it to two other volatile periods:
## 1) March - April 2020 due to COVID crash
## 2) late Feb - mid March 2026 due to war crisis in the Middle East

con.sql("""SELECT * FROM hsbc_volatility
            WHERE date BETWEEN '2025-04-01' AND '2025-04-30'
            ORDER BY date""").show()

con.sql("""SELECT * FROM hsbc_volatility
            WHERE date BETWEEN '2020-04-01' AND '2020-04-30'
            ORDER BY date""").show()

con.sql("""SELECT * FROM hsbc_volatility
            WHERE date BETWEEN '2026-04-01' AND '2026-04-30'
            ORDER BY date""").show()
# Out:
# ┌─────────────────────┬──────────────────────┬───────────────────────────┐
# │        date         │    volatility_20d    │ annualised_volatility_20d │
# │      timestamp      │        double        │          double           │
# ├─────────────────────┼──────────────────────┼───────────────────────────┤
# │ 2025-04-30 00:00:00 │  0.04057475365984521 │        0.6441042461499497 │
# │ 2025-05-06 00:00:00 │ 0.040558834806727735 │        0.6438515421909123 │
# │ 2025-05-07 00:00:00 │ 0.040547115977773815 │        0.6436655115484985 │
# │ 2025-05-02 00:00:00 │ 0.040509078719026044 │        0.6430616887852912 │
# │ 2025-04-29 00:00:00 │ 0.040447342266322246 │        0.6420816529812019 │
# │ 2025-05-08 00:00:00 │  0.04026867649646177 │        0.6392454218120976 │
# │ 2025-04-23 00:00:00 │  0.04005835711762127 │        0.6359067051782403 │
# │ 2025-04-24 00:00:00 │ 0.040033197947493875 │        0.6355073157341412 │
# ...

# %%
### Moving averages: 20-day moving average, 50-day moving average, and 200-day moving average
### are calculated. 

con.execute("""
CREATE OR REPLACE VIEW hsbc_ma AS
SELECT date, close,
    ROW_NUMBER() OVER (ORDER BY date) AS rn,
    AVG(close) OVER (ORDER BY date ROWS BETWEEN 19 PRECEDING AND CURRENT ROW) AS ma20,
    AVG(close) OVER (ORDER BY date ROWS BETWEEN 49 PRECEDING AND CURRENT ROW) AS ma50,
    AVG(close) OVER (ORDER BY date ROWS BETWEEN 199 PRECEDING AND CURRENT ROW) AS ma200
FROM hsbc_return
WHERE daily_return IS NOT NULL;
""")

## Locating the date of the historical cross signal using the ma50 and ma200 of HSBC.
##The graph of the moving averages should be plotted to confirm the dates and nature of these cross signals.

con.execute("""
CREATE OR REPLACE VIEW hsbc_cross AS
SELECT date,close,ma50,ma200,
    CASE 
        WHEN ma50 > ma200 AND LAG(ma50) OVER (ORDER BY date) <= LAG(ma200) OVER (ORDER BY date) THEN 'golden_cross'
        WHEN ma50 < ma200 AND LAG(ma50) OVER (ORDER BY date) >= LAG(ma200) OVER (ORDER BY date) THEN 'death_cross'
        ELSE NULL
    END AS cross_signal
FROM hsbc_ma
WHERE rn >= 200;
""")

con.sql("""
SELECT date, close, ma50, ma200,cross_signal
    FROM hsbc_cross
    WHERE cross_signal IS NOT NULL
""").show()

## Note: SQL applies WHERE before window functions are calculated. Using LAG() to find previous ma50,ma200 would result in
## the previous ma50,ma200 when there was a cross_signal.

## Note: the death cross signal on 17/03/2020 is not realiable due to insufficient number of days to calculate ma200. There
## are only 51 days before that in this datset. ROW_NUMBER() is used to find out when ma200 is genuine, leaving only
## 5 remaining cross signals
# Out:
# ┌─────────────────────┬────────────────────┬───────────────────┬────────────────────┬──────────────┐
# │        date         │       close        │       ma50        │       ma200        │ cross_signal │
# │      timestamp      │       double       │      double       │       double       │   varchar    │
# ├─────────────────────┼────────────────────┼───────────────────┼────────────────────┼──────────────┤
# │ 2020-12-22 00:00:00 │ 28.186403274536133 │   26.773154296875 │  26.73314326286316 │ golden_cross │
# │ 2021-08-27 00:00:00 │  31.15025329589844 │ 32.14828022003174 │ 32.149848985671994 │ death_cross  │
# │ 2021-12-06 00:00:00 │  33.26402282714844 │ 33.21580780029297 │ 33.151382007598876 │ golden_cross │
# │ 2022-09-08 00:00:00 │  36.84640884399414 │ 38.22396614074707 │  38.25565107345581 │ death_cross  │
# │ 2023-01-19 00:00:00 │  43.85187530517578 │ 37.26750823974609 │ 37.154163427352906 │ golden_cross │
# ...

# %%
### Plotting ma50 and ma200 to identify crosses to confirm the dates from previous lines.

ma_df = con.sql("SELECT * FROM hsbc_ma ORDER BY date").df()
ma200_df = ma_df[ma_df["rn"]>=200]
cross_df = con.sql("SELECT * FROM hsbc_cross WHERE cross_signal IS NOT NULL").df()

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(ma_df["date"],ma_df["close"],label="Close",color="lightgrey",linewidth=1)
ax.plot(ma_df["date"],ma_df["ma50"], label="MA_50",color="blue",linewidth=1)
ax.plot(ma200_df["date"],ma200_df["ma200"],label="MA_200",color="red",linewidth=1)     ## MA200 only plotted from day>=200

golden = cross_df[cross_df["cross_signal"]=="golden_cross"]
death = cross_df[cross_df["cross_signal"]=="death_cross"]
ax.scatter(golden["date"],(golden["ma50"]+golden["ma200"])/2,color="black",marker="x",s=10,zorder=5)
ax.scatter(death["date"],(death["ma50"]+death["ma200"])/2,color="black",marker="x",s=10,zorder=5,label="Cross Signals")

ax.legend()
ax.set_title("HSBC (0005.HK): Price, 50/200-day MA, and Cross Signals")
plt.show()

# %%
### Correlate the three stock prices against the HSI index, and against one another to investigate how their prices
### change with one another. First create return tables for each stock and the HSI index, then use CORR() to correlate.

con.execute("""
CREATE OR REPLACE VIEW tencent_return AS
SELECT date, close, LAG(close) OVER (ORDER BY DATE) AS prev_close, (close/prev_close -1) AS daily_return
FROM pg.tencent_0700
""")

con.execute("""
CREATE OR REPLACE VIEW hkex_return AS
SELECT date, close, LAG(close) OVER (ORDER BY DATE) AS prev_close, (close/prev_close -1) AS daily_return
FROM pg.hkex_0388
""")

con.execute("""
CREATE OR REPLACE VIEW hsi_return AS
SELECT date, close, LAG(close) OVER (ORDER BY DATE) AS prev_close, (close/prev_close -1) AS daily_return
FROM pg.hsi_index
""")

correlation = con.sql("""
SELECT 
    CORR(h.daily_return,b.daily_return) AS hsi_hsbc_corr,
    CORR(h.daily_return,t.daily_return) AS hsi_tenc_corr,
    CORR(h.daily_return,x.daily_return) AS hsi_hkex_corr,
    CORR(b.daily_return,t.daily_return) AS hsbc_tenc_corr,
    CORR(b.daily_return,x.daily_return) AS hsbc_hkex_corr,
    CORR(t.daily_return,x.daily_return) AS tenc_hkex_corr
FROM hsbc_return b
    JOIN tencent_return t ON b.date = t.date
    JOIN hkex_return x ON b.date = x.date
    JOIN hsi_return h ON b.date = h.date
""")

correlation.show()
# Out:
# ┌────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │   hsi_hsbc_corr    │   hsi_tenc_corr    │   hsi_hkex_corr    │   hsbc_tenc_corr   │   hsbc_hkex_corr    │   tenc_hkex_corr   │
# │       double       │       double       │       double       │       double       │       double        │       double       │
# ├────────────────────┼────────────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ 0.5389862978794799 │ 0.7947716975479228 │ 0.8135679150105615 │ 0.2632739153449799 │ 0.33795678300407556 │ 0.6717905104357679 │
# └────────────────────┴────────────────────┴────────────────────┴────────────────────┴─────────────────────┴────────────────────┘

# %%
### Correlating data against one another to see how individual stock prices move with/opposite to the others

#
#correlation_data = correlation.df().iloc[0]
#
#ticker_list = ["HSBC","Tencent","HKEX","HSI"]
#matrix = pd.DataFrame(index=ticker_list, columns=ticker_list, dtype=float)
#
#for t in ticker_list:
#    matrix.loc[t,t]=1.0
#
#matrix.loc["HSBC","HSI"]=matrix.loc["HSI","HSBC"]=correlation_data["hsi_hsbc_corr"]
#matrix.loc["Tencent","HSI"]=matrix.loc["HSI","Tencent"]=correlation_data["hsi_tenc_corr"]
#matrix.loc["HKEX","HSI"]=matrix.loc["HSI","HKEX"]=correlation_data["hsi_hkex_corr"]
#matrix.loc["HSBC","Tencent"]=matrix.loc["Tencent","HSBC"]=correlation_data["hsbc_tenc_corr"]
#matrix.loc["HSBC","HKEX"]=matrix.loc["HKEX","HSBC"]=correlation_data["hsbc_tenc_corr"]
#matrix.loc["Tencent","HKEX"]=matrix.loc["HKEX","Tencent"]=correlation_data["tenc_hkex_corr"]
#
#print(matrix.round(3))


## Refining the above codes into a loop so that different comparisons can be easily done. 

## return_views has to be changed into the stocks that are compared, automate this when code is finished.
return_views = {
    'hsbc': 'hsbc_return',
    'tencent': 'tencent_return',
    'hkex': 'hkex_return',
    'hsi': 'hsi_return',
}

ticker_list = list(return_views.keys())
matrix = pd.DataFrame(index=ticker_list, columns=ticker_list, dtype=float)

for t in ticker_list:
    matrix.loc[t, t] = 1.0

for t1, t2 in itertools.combinations(ticker_list, 2):
    view1, view2 = return_views[t1], return_views[t2]
    result = con.sql(f"""
        SELECT CORR(a.daily_return, b.daily_return) AS corr_val
        FROM {view1} a
        JOIN {view2} b ON a.date = b.date
    """).fetchone()
    corr_val = result[0]
    matrix.loc[t1, t2] = corr_val
    matrix.loc[t2, t1] = corr_val

print(matrix.round(3))
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[10], line 40
#      36     matrix.loc[t, t] = 1.0
#      37
#      38 for t1, t2 in itertools.combinations(ticker_list, 2):
#      39     view1, view2 = return_views[t1], return_views[t2]
# ---> 40     result = con.sql(f"""
#      41         SELECT CORR(a.daily_return, b.daily_return) AS corr_val
#      42         FROM {view1} a
#      43         JOIN {view2} b ON a.date = b.date
#
# CatalogException: Catalog Error: Table with name tencent_return does not exist!
# Did you mean "pg.tencent_0700"?

# %%
### Finding beta of each stock against the HSI index - how much the stock prices amplify the market movements.

return_views = {
    'hsbc': 'hsbc_return',
    'tencent': 'tencent_return',
    'hkex': 'hkex_return',
}

ticker_list = list(return_views.keys())
column_name = 'Beta vs HSI'
matrix_avg = pd.DataFrame(index=ticker_list, columns=[column_name], dtype=float)

for t in ticker_list:
    view = return_views[t]
    result = con.sql(f"""
        SELECT COVAR_SAMP(a.daily_return,h.daily_return)/VAR_SAMP(h.daily_return) AS beta
        FROM {view} a
        JOIN hsi_return h ON a.date=h.date
        """).fetchone()
    beta = result[0]
    matrix_avg.loc[t] = beta

print(matrix_avg.round(3))
# Out:
#          Beta vs HSI
# hsbc           0.584
# tencent        1.268
# hkex           1.117

# %%
### Calculating the beta of each stock against the HSI index - how much the stock prices amplify the market movements.
### The 60-day rolling beta of each stock is also calculated, and plotted against time for each stock. They are compared
### to the full-period average beta to show the fluctuation of the beta across the 6-year period.

### 60 days are used to calculated the variance and covariance to ensure that there are enough data points to be considered,
### and the time period is also short enough so that specific changes during a significant fluctuation are not smoothed out
### by the length of the period.

return_views = {
    'hsbc': 'hsbc_return',
    'tencent': 'tencent_return',
    'hkex': 'hkex_return',
}

ticker_list = list(return_views.keys())
column_name = 'Beta vs HSI'
beta_avg = pd.DataFrame(index=ticker_list, columns=[column_name], dtype=float)
corr_avg = pd.DataFrame(index=ticker_list, columns=[column_name], dtype=float)

for t in ticker_list:
    view = return_views[t]
    
    #Average beta over the whole period
    result = con.sql(f"""
        SELECT COVAR_SAMP(a.daily_return,h.daily_return)/VAR_SAMP(h.daily_return) AS beta
        FROM {view} a
        JOIN hsi_return h ON a.date=h.date
        """).fetchone()
    beta = result[0]
    beta_avg.loc[t] = beta

    #Average correlation
    result = con.sql(f"""
        SELECT CORR(a.daily_return,h.daily_return) AS corr
        FROM {view} a
        JOIN hsi_return h ON a.date=h.date
        """).fetchone()
    corr = result[0]
    corr_avg.loc[t] = corr

    #60-day rolling beta
    con.execute(f"""
        CREATE OR REPLACE VIEW rolling_beta AS
        SELECT 
            a.date,
            ROW_NUMBER() OVER (ORDER BY a.date) AS rn,
            COVAR_SAMP(a.daily_return,h.daily_return) OVER (ORDER BY a.date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW)
                /VAR_SAMP(h.daily_return) OVER (ORDER BY a.date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) 
                AS beta_val
        FROM {view} a
        JOIN hsi_return h ON a.date=h.date
        """)
    con.execute(f"""CREATE OR REPLACE VIEW rolling_60d_beta AS SELECT date, beta_val 
                    FROM rolling_beta WHERE rn>=60""")

    #60-day rolling correlation
    con.execute(f"""
        CREATE OR REPLACE VIEW rolling_corr AS
        SELECT
            a.date,
            ROW_NUMBER() OVER (ORDER BY a.date) AS rn,
            CORR(a.daily_return,h.daily_return) OVER (ORDER BY a.date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS corr_val
            FROM {view} a
            JOIN hsi_return h ON a.date=h.date
        """)
    con.execute(f"""CREATE OR REPLACE VIEW rolling_60d_corr AS SELECT date, corr_val
                    FROM rolling_corr WHERE rn>=60""")

    #DataFrame
    beta_df = con.sql("SELECT * FROM rolling_60d_beta ORDER BY date").df()
    corr_df = con.sql("SELECT * FROM rolling_60d_corr ORDER BY date").df()
    

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))

    ax1.plot(beta_df["date"],beta_df["beta_val"], color="blue", label=f"{t} rolling beta")
    ax1.axhline(1.0, color="gray", linestyle="--", linewidth=1, label="Beta = 1 (market-level)")
    ax1.axhline(beta_avg.loc[t,column_name], color="blue", linestyle=":", linewidth=1, label="Full-period average beta")
    ax1.set_ylabel("Beta",color="blue")
    ax1.legend()

    ax2.plot(corr_df["date"],corr_df["corr_val"], color="green", label=f"{t} rolling correlation")
    ax2.axhline(corr_avg.loc[t,column_name], color="green", linestyle=":", linewidth=1, label="Full-period average correlation")
    ax2.set_ylabel("Correlation",color="green")
    ax2.legend()

    
    ax1.set_title(f"{t}: 60-Day Rolling Beta vs. HSI")
    ax2.set_title(f"{t}: 60-Day Rolling Correlation vs. HSI")
    plt.show()

print(beta_avg.round(3))
# Out:
#          Beta vs HSI
# hsbc           0.584
# tencent        1.268
# hkex           1.117
